# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreejathalla/RL-Lab/blob/main/renfi_ass_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question-1

# %%
n = int(input("Enter number of machines: "))

names = []
q_values = []

for i in range(n):
    name = input("Enter machine name: ")
    rewards = list(map(int, input("Enter rewards: ").split()))

    total = 0

    for reward in rewards:
        total = total + reward

    q = total / len(rewards)

    names.append(name)
    q_values.append(q)

print("\n--- Estimated Values ---")

for i in range(n):
    print("Machine", names[i])
    print("Q(" + names[i] + ") =", round(q_values[i], 2))

highest = 0

for i in range(1, n):
    if q_values[i] > q_values[highest]:
        highest = i

print("\nGreedy Selected Machine:", names[highest])
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
# Enter machine name: B
# Enter rewards: 6 7
# Enter machine name: C
# Enter rewards: 5 4 6
#
# --- Estimated Values ---
# Machine A
# Q(A) = 3.0
# Machine B
# Q(B) = 6.5
# Machine C
# Q(C) = 5.0
#
# Greedy Selected Machine: B

# %% [markdown]
# Question 2

# %%
n = int(input("Enter number of machines: "))

names = []
rewards_list = []
Q = []
N = []


for i in range(n):
    name = input("Enter machine name: ")
    rewards = list(map(int, input("Enter rewards: ").split()))

    names.append(name)
    rewards_list.append(rewards)
    Q.append(0)
    N.append(0)



print("\n--- Incremental Updates ---")

for i in range(n):
    print("\nMachine", names[i])

    for reward in rewards_list[i]:

        N[i] = N[i] + 1

        # Incremental update formula
        Q[i] = Q[i] + (reward - Q[i]) / N[i]

        print("Reward =", reward)
        print("N =", N[i])
        print("Q =", round(Q[i], 2))



print("\n--- Final Estimated Values ---")

for i in range(n):
    print("Machine", names[i])
    print("Rewards:", rewards_list[i])
    print("N =", N[i])
    print("Q =", round(Q[i], 2))



highest = 0

for i in range(1, n):
    if Q[i] > Q[highest]:
        highest = i

print("\nGreedy Selected Machine:", names[highest])
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
# Enter machine name: B
# Enter rewards: 6 7
# Enter machine name: C
# Enter rewards: 5 4 6
#
# --- Incremental Updates ---
#
# Machine A
# Reward = 3
# N = 1
# Q = 3.0
# Reward = 2
# N = 2
# Q = 2.5
# Reward = 4
# N = 3
# Q = 3.0
#
# Machine B
# Reward = 6
# N = 1
# Q = 6.0
# Reward = 7
# N = 2
# Q = 6.5
#
# Machine C
# Reward = 5
# N = 1
# Q = 5.0
# Reward = 4
# N = 2
# Q = 4.5
# Reward = 6
# N = 3
# Q = 5.0
#
# --- Final Estimated Values ---
# Machine A
# Rewards: [3, 2, 4]
# N = 3
# Q = 3.0
# Machine B
# Rewards: [6, 7]
# N = 2
# Q = 6.5
# Machine C
# Rewards: [5, 4, 6]
# N = 3
# Q = 5.0
#
# Greedy Selected Machine: B
