# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreejathalla/RL-Lab/blob/main/renfi_ass_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question-01

# %%
import random

# Part A - Machine Initialization
machines = ['A', 'B', 'C']

# Number of plays
N_play = 10

# Exploration probability
epsilon = 0.2

# Initialize N, R and Q tables
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': 0, 'B': 0, 'C': 0}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}

print("Initial Tables")
print("N =", N)
print("R =", R)
print("Q =", Q)

# Play the machines 10 times
for play in range(1, N_play + 1):

    # Generate random number
    r = random.random()

    # Epsilon-Greedy Decision
    if r < epsilon:
        # Exploration
        selected_machine = random.choice(machines)
        decision = "Exploration"
    else:
        # Exploitation
        max_q = max(Q.values())

        # Select machine with highest Q-value
        best_machines = [
            machine for machine in machines
            if Q[machine] == max_q
        ]

        selected_machine = random.choice(best_machines)
        decision = "Exploitation"

    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Selected Machine:", selected_machine)

    # Part C - Reward Collection
    reward = float(input("Enter reward: "))

    # Part D - Update N
    N[selected_machine] += 1

    # Update total reward R
    R[selected_machine] += reward

    # Incremental sample-average formula
    Q[selected_machine] = (
        Q[selected_machine]
        + (reward - Q[selected_machine]) / N[selected_machine]
    )

    print("Updated N:", N)
    print("Updated R:", R)
    print("Updated Q:", Q)


# Part E - Display Final Results
print("\n========== FINAL RESULTS ==========")

print("\nMachine\tN\tR\tQ-value")

for machine in machines:
    print(
        machine,
        "\t", N[machine],
        "\t", R[machine],
        "\t", round(Q[machine], 2)
    )

print("\nFinal Participation Counts:")
print(N)

print("\nFinal Rewards:")
print(R)

print("\nFinal Q-values:")
print(Q)
# Out:
# Initial Tables
# N = {'A': 0, 'B': 0, 'C': 0}
# R = {'A': 0, 'B': 0, 'C': 0}
# Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
#
# Play 1
# Random number: 0.1621
# Decision: Exploration
# Selected Machine: C
# Enter reward: 3
# Updated N: {'A': 0, 'B': 0, 'C': 1}
# Updated R: {'A': 0, 'B': 0, 'C': 3.0}
# Updated Q: {'A': 0.0, 'B': 0.0, 'C': 3.0}
#
# Play 2
# Random number: 0.092
# Decision: Exploration
# Selected Machine: C
# Enter reward: 4
# Updated N: {'A': 0, 'B': 0, 'C': 2}
# Updated R: {'A': 0, 'B': 0, 'C': 7.0}
# Updated Q: {'A': 0.0, 'B': 0.0, 'C': 3.5}
#
# Play 3
# Random number: 0.6241
# Decision: Exploitation
# Selected Machine: C
# Enter reward: 6
# Updated N: {'A': 0, 'B': 0, 'C': 3}
# Updated R: {'A': 0, 'B': 0, 'C': 13.0}
# Updated Q: {'A': 0.0, 'B': 0.0, 'C': 4.333333333333333}
#
# Play 4
# Random number: 0.795
# Decision: Exploitation
# Selected Machine: C
# Enter reward: 2
# Updated N: {'A': 0, 'B': 0, 'C': 4}
# Updated R: {'A': 0, 'B': 0, 'C': 15.0}
# ...
